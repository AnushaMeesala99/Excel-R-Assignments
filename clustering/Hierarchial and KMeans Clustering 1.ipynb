# %% [markdown]
# # Hierarchical Clustering

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("EastWestAirlines.csv")
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)
#Normalizing

# %%
norm=norm_func(data.iloc[:,1:])
norm
#Removing ID column
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch #Creating dendrogram
z= linkage(norm, method="complete",metric= "euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(z)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering 
h_complete=AgglomerativeClustering(n_clusters=5, linkage="complete", affinity="euclidean").fit(norm)
clusterlabels = pd.Series(h_complete.labels_)
clusterlabels
data["Clusters"]=clusterlabels  # creating a  new column and assigning it to new column 
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data.Clusters.value_counts()
# Out:
# 0    2495
# 2    1144
# 1     325
# 4      31
# 3       4
# Name: Clusters, dtype: int64

# %%
data.iloc[:,1:11].groupby(data.Clusters).mean()
# Out:
#                 Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Clusters
# 0          59968.433667   88.883768   1.712224   1.000401   1.011222
# 1         157084.578462  208.673846   4.661538   1.000000   1.061538
# 2          80173.963287  248.550699   2.104895   1.009615   1.000874
# 3         131999.500000  347.000000   2.500000   1.000000   1.000000
# 4          45515.064516   32.258065   1.000000   2.483871   1.000000
#
#            Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# Clusters
# 0         10271.530261     9.105812         227.797194         0.656112
# 1         70477.086154    23.249231        1019.433846         3.196923
# 2         16882.864510    13.412587         739.958916         2.236888
# 3         65634.250000    69.250000       19960.000000        49.250000
# 4         14618.870968    16.129032         443.225806         1.967742
#
#           Days_since_enroll
# Clusters
# 0               3825.392786
# ...

# %% [markdown]
# # K means clustering

# %%
kdata=pd.read_csv("EastWestAirlines.csv")
kdata
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
from sklearn.cluster import KMeans
fig=plt.figure(figsize=(10,8))
wcss=[]
for i in range(1,11):
    clf= KMeans(n_clusters=i)
    clf.fit(norm)
    wcss.append(clf.inertia_)
plt.plot(range(1,11),wcss)
plt.ylabel("WCSS") 
plt.xlabel("Number of Clusters")
plt.title("The Elbow Curve")
# Out:
# Text(0.5, 1.0, 'The Elbow Curve')

# %%
clf=KMeans(n_clusters=5)

# %%
clf.labels_
# Out:
# array([2, 2, 2, ..., 1, 3, 3])

# %%
sd=pd.Series(clf.labels_)
sd
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 3994    4
# 3995    4
# 3996    1
# 3997    3
# 3998    3
# Length: 3999, dtype: int32

# %%
kdata["Clusters"]=sd
kdata
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
kdata.iloc[:,1:11].groupby(kdata.Clusters).mean()
# Out:
#                 Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Clusters
# 0         118297.325243   73.467638   3.584142   1.001618   1.022654
# 1         108317.387376  198.336634   3.915842   1.001238   1.025990
# 2          49921.633641   89.903226   1.122120   1.019585   1.001152
# 3          33097.301357   94.131783   1.070736   1.016473   1.006783
# 4          83529.153046  290.453195   1.156018   1.032689   1.008915
#
#            Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# Clusters
# 0         31384.393204    17.233010         224.100324         0.627832
# 1         45609.657178    20.201733         713.728960         2.142327
# 2          3467.074885     6.913594         243.834101         0.728111
# 3          3244.520349     6.173450         212.850775         0.603682
# 4          8850.395245    10.476969        1030.112927         3.148588
#
#           Days_since_enroll
# Clusters
# 0               4419.553398
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(kdata['Clusters'],kdata['Balance'], c=clf.labels_)
